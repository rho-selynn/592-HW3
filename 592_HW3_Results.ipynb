# %%
from torch import int64
import cv2 
import os 
import glob 
from google.colab.patches import cv2_imshow
import numpy as np
import torch
img_dir = "Images"
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
Images = [] 
for f1 in files: 
    img = cv2.imread(f1, 0) 
    Images.append(img)
Images = np.array(Images)
Images = (np.divide(Images, 255))
Images = Images.astype(float)

# %%
controlData = np.loadtxt('Robot Log/robot_log.csv', delimiter = ';', skiprows = 1, usecols = (1,2), dtype = float)
print(np.max(controlData[:,0]))
controlData[:,0] /= 15
# Out:
# 15.0

# %%
from torch.utils.data import TensorDataset
ImagesTrain = torch.tensor(Images[0:799])
steerDataTrain = torch.tensor(controlData[0:799, 0])
trainSteerDataset = TensorDataset(ImagesTrain, steerDataTrain)
ImagesTest = torch.tensor(Images[800:999])
steerDataTest = torch.tensor(controlData[800:999, 0])
testSteerDataset = TensorDataset(ImagesTest, steerDataTest)
throttleDataTrain = torch.tensor(controlData[0:799, 1])
trainThrottleDataset = TensorDataset(ImagesTrain, throttleDataTrain)
throttleDataTest = torch.tensor(controlData[800:999, 1])
testThrottleDataset = TensorDataset(ImagesTest, throttleDataTest)

# %%
steerTrainDataLoader = torch.utils.data.DataLoader(trainSteerDataset, batch_size=128, shuffle=True)
steerTestDataLoader = torch.utils.data.DataLoader(testSteerDataset, batch_size=128, shuffle=False)
throttleTrainDataLoader = torch.utils.data.DataLoader(trainThrottleDataset, batch_size=128, shuffle=True)
throttleTestDataLoader = torch.utils.data.DataLoader(testThrottleDataset, batch_size=128, shuffle=False)

# %%
class LR(torch.nn.Module):
    def __init__(self):
        super(LR, self).__init__()
        self.linear1 = torch.nn.Linear(160*320, 128) # W:784x128 , b:128x1 , parameters = [W,b]
        self.linear2 = torch.nn.Linear(128, 10)
        self.linear3 = torch.nn.Linear(10, 5)
        self.linear4 = torch.nn.Linear(5, 1)
    
    def forward(self, x):
        x = x.view(-1,160*320)
        transformed_x1 = self.linear1(x)
        transformed_x2 = self.linear2(transformed_x1)
        transformed_x3 = self.linear3(transformed_x2)
        transformed_x4 = self.linear4(transformed_x3)
        return transformed_x4

class LRthrottle(torch.nn.Module):
    def __init__(self):
        super(LRthrottle, self).__init__()
        self.linear1 = torch.nn.Linear(160*320, 128) # W:784x128 , b:128x1 , parameters = [W,b]
        self.linear2 = torch.nn.Linear(128, 10)
        self.linear3 = torch.nn.Linear(10, 5)
        self.linear4 = torch.nn.Linear(5, 1)
        self.activation = torch.nn.ReLU()
    
    def forward(self, x):
        x = x.view(-1,160*320)
        transformed_x1 = self.linear1(x)
        transformed_x2 = self.linear2(transformed_x1)
        transformed_x3 = self.linear3(transformed_x2)
        transformed_x4 = self.linear4(transformed_x3)
        #transformed_x4 = self.activation(transformed_x4)
        return transformed_x4

steerNet = LR()
steerOptimizer = torch.optim.Adam(steerNet.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()
criterionThrottle = torch.nn.L1Loss()
throttleNet = LRthrottle()
throttleOptimizer = torch.optim.Adam(throttleNet.parameters(), lr=0.01)

# %%
#steering trainer
train_loss_history = []
test_loss_history = []
for epoch in range(20):
    train_loss = 0.0
    test_loss = 0.0
    for i, data in enumerate(steerTrainDataLoader):
        images, labels = data
        images = images.to(torch.float32)
        labels = labels.to(torch.float32)
        steerOptimizer.zero_grad()
        predicted_output = steerNet(images.float())
        predicted_output = predicted_output.to(torch.float32)
        loss = criterion(predicted_output, labels)
        loss.backward()
        steerOptimizer.step()
        train_loss += loss.item()
    for i, data in enumerate(steerTestDataLoader):
        with torch.no_grad():
            images, labels = data
            predicted_output = steerNet(images.float())
            loss = criterion(predicted_output, labels.long())
            test_loss += loss.item()
    train_loss = train_loss/len(steerTrainDataLoader)
    test_loss = test_loss/len(steerTestDataLoader)
    train_loss_history.append(train_loss)
    test_loss_history.append(test_loss)
    print('Epoch %s finished with train loss %s and test loss %s'%(epoch, train_loss, test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([31])) that is different to the input size (torch.Size([31, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([71])) that is different to the input size (torch.Size([71, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 0 finished with train loss 81.72508937971932 and test loss 46.36457061767578
# Epoch 1 finished with train loss 56.48515183585031 and test loss 11.300064086914062
# Epoch 2 finished with train loss 9.1688118321555 and test loss 21.957029342651367
# Epoch 3 finished with train loss 10.801085991518837 and test loss 0.07292334549129009
# Epoch 4 finished with train loss 3.8708798629896983 and test loss 4.304843425750732
# Epoch 5 finished with train loss 1.8042827972343989 and test loss 0.8607746660709381
# Epoch 6 finished with train loss 1.5721244641712733 and test loss 0.6726866960525513
# Epoch 7 finished with train loss 0.5098892322608403 and test loss 0.4422624558210373
# Epoch 8 finished with train loss 0.6203276131834302 and test loss 0.033756616525352
# Epoch 9 finished with train loss 0.39949839455740793 and test loss 0.2062266543507576
# Epoch 10 finished with train loss 0.3053705926452364 and test loss 0.045125687494874
# Epoch 11 finished with train loss 0.34559762477874756 and test loss 0.03171032667160034
# Epoch 12 finished with train loss 0.29528258740901947 and test loss 0.08212831988930702
# Epoch 13 finished with train loss 0.29785430644239697 and test loss 0.02939256653189659
# Epoch 14 finished with train loss 0.30200121658188955 and test loss 0.028785094618797302
# Epoch 15 finished with train loss 0.28908099446977886 and test loss 0.03558290284126997
# Epoch 16 finished with train loss 0.29787240283829824 and test loss 0.02985504548996687
# Epoch 17 finished with train loss 0.2941160116876875 and test loss 0.0399943757802248
# Epoch 18 finished with train loss 0.28285345648016247 and test loss 0.0247915955260396
# Epoch 19 finished with train loss 0.28726907074451447 and test loss 0.034229204058647156

# %%
#throttle trainer
train_loss_history = []
test_loss_history = []
for epoch in range(40):
    train_loss = 0.0
    test_loss = 0.0
    for i, data in enumerate(throttleTrainDataLoader):
        images, labels = data
        images = images.to(torch.float32)
        labels = labels.to(torch.float32)
        throttleOptimizer.zero_grad()
        predicted_output = throttleNet(images.float())
        predicted_output = predicted_output.to(torch.float32)
        loss = criterion(predicted_output, labels)
        loss.backward()
        throttleOptimizer.step()
        train_loss += loss.item()
    for i, data in enumerate(throttleTestDataLoader):
        with torch.no_grad():
            images, labels = data
            predicted_output = throttleNet(images.float())
            loss = criterion(predicted_output, labels.long())
            test_loss += loss.item()
    train_loss = train_loss/len(throttleTrainDataLoader)
    test_loss = test_loss/len(throttleTestDataLoader)
    train_loss_history.append(train_loss)
    test_loss_history.append(test_loss)
    print('Epoch %s finished with train loss %s and test loss %s'%(epoch, train_loss, test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([31])) that is different to the input size (torch.Size([31, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([71])) that is different to the input size (torch.Size([71, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 0 finished with train loss 0.2264768523829324 and test loss 0.1814398393034935
# Epoch 1 finished with train loss 0.2347784468105861 and test loss 0.12995517253875732
# Epoch 2 finished with train loss 0.2350929762635912 and test loss 0.07058463245630264
# Epoch 3 finished with train loss 0.23590699902602605 and test loss 0.06044740229845047
# Epoch 4 finished with train loss 0.22246872740132467 and test loss 0.09885851666331291
# Epoch 5 finished with train loss 0.23030151426792145 and test loss 0.10410498082637787
# Epoch 6 finished with train loss 0.22380402897085463 and test loss 0.1745888888835907
# Epoch 7 finished with train loss 0.2262152177946908 and test loss 0.15760134905576706
# Epoch 8 finished with train loss 0.23904795518943242 and test loss 0.12293196842074394
# Epoch 9 finished with train loss 0.2372493531022753 and test loss 0.035394784063100815
# Epoch 10 finished with train loss 0.22640949061938695 and test loss 0.03442592732608318
# Epoch 11 finished with train loss 0.22994198117937362 and test loss 0.10795317217707634
# Epoch 12 finished with train loss 0.2294411701815469 and test loss 0.16273000836372375
# Epoch 13 finished with train loss 0.22134337042059218 and test loss 0.13875391334295273
# Epoch 14 finished with train loss 0.2201708448784692 and test loss 0.07199384272098541
# Epoch 15 finished with train loss 0.22086335292884282 and test loss 0.09214822947978973
# Epoch 16 finished with train loss 0.2174328033413206 and test loss 0.09238395094871521
# Epoch 17 finished with train loss 0.22664996981620789 and test loss 0.10116202756762505
# Epoch 18 finished with train loss 0.22765872308186122 and test loss 0.10285932570695877
# Epoch 19 finished with train loss 0.22905525139399938 and test loss 0.26278845965862274
# Epoch 20 finished with train loss 0.23063149409634726 and test loss 0.1588866487145424
# Epoch 21 finished with train loss 0.2324244465146746 and test loss 0.15921641886234283
# Epoch 22 finished with train loss 0.2483786450965064 and test loss 0.16164282709360123
# Epoch 23 finished with train loss 0.25208568572998047 and test loss 0.08102447167038918
# Epoch 24 finished with train loss 0.2338180754865919 and test loss 0.009429302532225847
# Epoch 25 finished with train loss 0.24731246488434927 and test loss 0.028671384789049625
# Epoch 26 finished with train loss 0.23231350098337447 and test loss 0.10588718950748444
# Epoch 27 finished with train loss 0.21873738936015538 and test loss 0.14205493032932281
# Epoch 28 finished with train loss 0.22539545169898442 and test loss 0.21641701459884644
# Epoch 29 finished with train loss 0.2369441773210253 and test loss 0.10493650659918785
# Epoch 30 finished with train loss 0.22417591512203217 and test loss 0.04781731963157654
# Epoch 31 finished with train loss 0.22042999735900334 and test loss 0.05831081233918667
# Epoch 32 finished with train loss 0.2317920731646674 and test loss 0.12575041130185127
# Epoch 33 finished with train loss 0.21792283015591757 and test loss 0.10642928257584572
# Epoch 34 finished with train loss 0.22127628326416016 and test loss 0.1750248819589615
# Epoch 35 finished with train loss 0.2246149480342865 and test loss 0.14457422494888306
# Epoch 36 finished with train loss 0.22092641677175248 and test loss 0.14579972624778748
# Epoch 37 finished with train loss 0.21970999453748977 and test loss 0.08151156455278397
# Epoch 38 finished with train loss 0.22596852694238936 and test loss 0.09538904577493668
# Epoch 39 finished with train loss 0.22114249425274984 and test loss 0.07551407814025879

# %%
from torch import int64
import cv2 
import os 
import glob 
from google.colab.patches import cv2_imshow
import numpy as np
import torch
img_dir = "Images"
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
Images = [] 
for f1 in files: 
    img = cv2.imread(f1, 0) 
    Images.append(img)
Images = np.array(Images)
Images = (np.divide(Images, 255))
Images = Images.astype(float)
Images = torch.tensor(Images)

for i in np.linspace(1, 999, 100).astype(int):
  predicted_output_steer = steerNet(Images[i].float())
  predicted_output_throttle = throttleNet(Images.float()[i])
  correct_steer = controlData[i,0]
  correct_throttle = controlData[i,1]
  print ("correct steer: " + str(correct_steer) + " predicted steer: " + str(predicted_output_steer))
  print ("correct throttle: " + str(correct_throttle) + " predicted throttle: " + str(predicted_output_throttle))
# Out:
# correct steer: 0.0 predicted steer: tensor([[0.0929]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2651]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.3336]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2800]], grad_fn=<AddmmBackward0>)
# correct steer: -1.0 predicted steer: tensor([[0.0947]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3001]], grad_fn=<AddmmBackward0>)
# correct steer: 0.4833035333333333 predicted steer: tensor([[-0.0521]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3058]], grad_fn=<AddmmBackward0>)
# correct steer: 0.7374106666666667 predicted steer: tensor([[0.2806]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2817]], grad_fn=<AddmmBackward0>)
# correct steer: 0.5239568666666666 predicted steer: tensor([[0.1483]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2730]], grad_fn=<AddmmBackward0>)
# correct steer: 0.7197286666666667 predicted steer: tensor([[0.2311]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2461]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1966]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2637]], grad_fn=<AddmmBackward0>)
# correct steer: 0.6153696 predicted steer: tensor([[0.1626]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2550]], grad_fn=<AddmmBackward0>)
# correct steer: -0.6139736 predicted steer: tensor([[0.1671]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2769]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2706]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.4950394 predicted throttle: tensor([[0.2279]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[0.2545]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2793]], grad_fn=<AddmmBackward0>)
# correct steer: -0.5846032666666667 predicted steer: tensor([[0.2513]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2348]], grad_fn=<AddmmBackward0>)
# correct steer: -0.2789084 predicted steer: tensor([[0.0951]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2955]], grad_fn=<AddmmBackward0>)
# correct steer: -0.2124676 predicted steer: tensor([[0.0970]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2627]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[-0.1843]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2157]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[0.2736]], grad_fn=<AddmmBackward0>)
# correct throttle: -0.2111334 predicted throttle: tensor([[0.2258]], grad_fn=<AddmmBackward0>)
# correct steer: 0.4680255333333333 predicted steer: tensor([[0.1473]], grad_fn=<AddmmBackward0>)
# correct throttle: -0.2007148 predicted throttle: tensor([[0.2491]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[0.0928]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2656]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1317]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3163]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.3305]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2845]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2283]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2161]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0930]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3472]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2383]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3247]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0945]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2770]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1524]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2144]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0929]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2654]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.0036]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2739]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0924]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2558]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1484]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2731]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0561]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2129]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2431]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2683]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1466]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2563]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0787]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2859]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0928]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2654]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.0134]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2275]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1841]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2501]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.1436]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2388]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1102]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2578]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0853]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3592]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1484]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2731]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0648]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3325]], grad_fn=<AddmmBackward0>)
# correct steer: -1.0 predicted steer: tensor([[0.0952]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2943]], grad_fn=<AddmmBackward0>)
# correct steer: -1.0 predicted steer: tensor([[0.0929]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2654]], grad_fn=<AddmmBackward0>)
# correct steer: -0.8699220000000001 predicted steer: tensor([[0.0930]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2651]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1543]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.8000112 predicted throttle: tensor([[0.3087]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1237]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.3119]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.0839]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2367]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1575]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.3290]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2029]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2317]], grad_fn=<AddmmBackward0>)
# correct steer: 0.39196040000000004 predicted steer: tensor([[0.0929]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2650]], grad_fn=<AddmmBackward0>)
# correct steer: -0.3920092 predicted steer: tensor([[0.0836]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2952]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0928]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.5016795 predicted throttle: tensor([[0.2653]], grad_fn=<AddmmBackward0>)
# correct steer: -0.4131076 predicted steer: tensor([[0.2021]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2786]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2668]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2130]], grad_fn=<AddmmBackward0>)
# correct steer: 0.7196073333333334 predicted steer: tensor([[0.2862]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.2102943 predicted throttle: tensor([[0.2796]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1214]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.8998381 predicted throttle: tensor([[0.2992]], grad_fn=<AddmmBackward0>)
# correct steer: -1.0 predicted steer: tensor([[0.1860]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2764]], grad_fn=<AddmmBackward0>)
# correct steer: 0.7905446666666667 predicted steer: tensor([[0.0930]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2648]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[0.0930]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2648]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[-0.2541]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2242]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2795]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.1986]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[0.2702]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2119]], grad_fn=<AddmmBackward0>)
# correct steer: 0.5961376 predicted steer: tensor([[0.2605]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2129]], grad_fn=<AddmmBackward0>)
# correct steer: 1.0 predicted steer: tensor([[0.0476]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3045]], grad_fn=<AddmmBackward0>)
# correct steer: -0.992492 predicted steer: tensor([[0.1473]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.7946134 predicted throttle: tensor([[0.2493]], grad_fn=<AddmmBackward0>)
# correct steer: 0.6347847333333333 predicted steer: tensor([[0.3406]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.696148 predicted throttle: tensor([[0.2340]], grad_fn=<AddmmBackward0>)
# correct steer: -0.0716964 predicted steer: tensor([[0.1857]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.6061968 predicted throttle: tensor([[0.4193]], grad_fn=<AddmmBackward0>)
# correct steer: -0.05514284666666667 predicted steer: tensor([[0.0607]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.1028131 predicted throttle: tensor([[0.2575]], grad_fn=<AddmmBackward0>)
# correct steer: -0.3970168 predicted steer: tensor([[0.1483]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2730]], grad_fn=<AddmmBackward0>)
# correct steer: -0.1819336 predicted steer: tensor([[0.0958]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2612]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0927]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2658]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.0085]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.3329]], grad_fn=<AddmmBackward0>)
# correct steer: -1.0 predicted steer: tensor([[0.1056]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.3017]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1721]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2266]], grad_fn=<AddmmBackward0>)
# correct steer: 0.3966516 predicted steer: tensor([[0.1684]], grad_fn=<AddmmBackward0>)
# correct throttle: 1.0 predicted throttle: tensor([[0.2220]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1483]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2729]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2031]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2590]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1483]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2732]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1483]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2729]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.1628]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2659]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1936]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2877]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.3239]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2425]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2630]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2514]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1073]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2462]], grad_fn=<AddmmBackward0>)
# correct steer: 0.8702433333333333 predicted steer: tensor([[0.3905]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2922]], grad_fn=<AddmmBackward0>)
# correct steer: -0.401782 predicted steer: tensor([[0.0940]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.298929 predicted throttle: tensor([[0.3479]], grad_fn=<AddmmBackward0>)
# correct steer: 0.28929313333333334 predicted steer: tensor([[0.1484]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2732]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1473]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2489]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0935]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2548]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0927]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2654]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0599]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3064]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1460]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2281]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.0929]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2652]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.1080]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.4199]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1594]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2907]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1770]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2477]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[-0.0371]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.3852]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.2726]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2268]], grad_fn=<AddmmBackward0>)
# correct steer: 0.0 predicted steer: tensor([[0.1096]], grad_fn=<AddmmBackward0>)
# correct throttle: 0.0 predicted throttle: tensor([[0.2562]], grad_fn=<AddmmBackward0>)
